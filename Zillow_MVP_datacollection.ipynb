# %%
# Bibliotecas:
import pandas as pd
import requests
import json
import time

# configuração pandas (visualização de todas as colunas):
pd.set_option('display.max_columns', None)

# API key
rapid_api_key = 'eafb9dbb18msh3e4269211fff736p151375jsn4f220230814a'

# %% [markdown]
# **EXAMPLE WITH ZIP CODE AND KEYWORDS**

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"Philadelphia, pa","status_type":"ForSale","daysOn":"7","schoolsRating":"4"}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'props': [{'dateSold': None, 'propertyType': 'TOWNHOUSE', 'lotAreaValue': 1901, 'address': '7012 Charles St, Philadelphia, PA 19135', 'variableData': None, 'priceChange': None, 'zestimate': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/950bbb8bb25d7cb7652be4043b2f85c8-p_e.jpg', 'price': 239900, 'detailUrl': '/homedetails/7012-Charles-St-Philadelphia-PA-19135/10510325_zpid/', 'bedrooms': 3, 'contingentListingType': None, 'longitude': -75.045715, 'latitude': 40.03344, 'listingStatus': 'FOR_SALE', 'zpid': '10510325', 'listingSubType': {'is_FSBA': True}, 'rentZestimate': None, 'daysOnZillow': '2', 'bathrooms': 2, 'livingArea': 1350, 'country': 'USA', 'currency': 'USD', 'lotAreaUnit': 'sqft', 'hasImage': True}, {'dateSold': None, 'propertyType': 'SINGLE_FAMILY', 'lotAreaValue': 5000, 'address': '321 Fanshawe St, Philadelphia, PA 19111', 'variableData': None, 'priceChange': None, 'zestimate': 293500, 'imgSrc': 'https://photos.zillowstatic.com/fp/84335bedc75331e4dd291441c1a9d0fb-p_e.
# ...

# %%
response.json()
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1901,
#    'address': '7012 Charles St, Philadelphia, PA 19135',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/950bbb8bb25d7cb7652be4043b2f85c8-p_e.jpg',
#    'price': 239900,
#    'detailUrl': '/homedetails/7012-Charles-St-Philadelphia-PA-19135/10510325_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -75.045715,
#    'latitude': 40.03344,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '10510325',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': '2',
#    'bathrooms': 2,
#    'livingArea': 1350,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5000,
#    'address': '321 Fanshawe St, Philadelphia, PA 19111',
# ...

# %%
zillow_listings = pd.json_normalize(data=response.json()['props'])
zillow_listings.head()
# Out:
#   dateSold   propertyType  lotAreaValue  \
# 0     None      TOWNHOUSE   1901.000000
# 1     None  SINGLE_FAMILY   5000.000000
# 2     None  SINGLE_FAMILY   8816.000000
# 3     None      TOWNHOUSE   1717.000000
# 4     None  SINGLE_FAMILY      0.867769
#
#                                       address  variableData  priceChange  \
# 0     7012 Charles St, Philadelphia, PA 19135           NaN          NaN
# 1     321 Fanshawe St, Philadelphia, PA 19111           NaN          NaN
# 2  9527 Northeast Ave, Philadelphia, PA 19115           NaN          NaN
# 3       2013 74th Ave, Philadelphia, PA 19138           NaN          NaN
# 4    8760 Stenton Ave, Philadelphia, PA 19118           NaN          NaN
#
#    zestimate                                             imgSrc   price  \
# 0        NaN  https://photos.zillowstatic.com/fp/950bbb8bb25...  239900
# 1   293500.0  https://photos.zillowstatic.com/fp/84335bedc75...  299000
# ...

# %%
zillow_listings.shape
# Out:
# (41, 31)

# %%
zillow_listings.to_excel('Listings_Philadelphia_7d.xlsx', index=False)

# %%
zillow_listings.daysOnZillow.unique()
# Out:
# array(['2', '4', -1, '1', '3', '5', '7', '6'], dtype=object)

# %%
zillow_listings.describe()
# Out:
#        lotAreaValue  variableData  priceChange      zestimate          price  \
# count     40.000000           0.0          1.0      29.000000      41.000000
# mean    2350.440950           NaN      15000.0  345596.551724  341187.731707
# std     2104.341390           NaN          NaN  162108.857788  172745.058615
# min        0.290037           NaN      15000.0  131200.000000   35000.000000
# 25%     1047.500000           NaN      15000.0  239900.000000  235000.000000
# 50%     1653.000000           NaN      15000.0  293500.000000  299900.000000
# 75%     2898.000000           NaN      15000.0  419500.000000  385000.000000
# max     9370.000000           NaN      15000.0  810900.000000  895000.000000
#
#         bedrooms  longitude   latitude  rentZestimate  bathrooms   livingArea
# count  41.000000  41.000000  41.000000      37.000000  40.000000    41.000000
# mean    3.658537 -75.127901  40.025685    2051.162162   2.375000  1803.317073
# ...
